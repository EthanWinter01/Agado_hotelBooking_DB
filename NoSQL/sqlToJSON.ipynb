# %%
import json
import re
from bson import ObjectId  # Simulating MongoDB's ObjectId
import datetime

id_counters = {
    "registered": 500000001,
    "unregistered": 100000001,
    "admin": 900000001
}

def hash_password(password):
    return "hashed_" + password  # Simulated hashing function

def generate_user_id(user_type):
    user_id = id_counters.get(user_type)
    if not user_id:
        raise ValueError("Invalid user type")
    
    # ID limits
    limits = {
        "registered": 899999999,
        "unregistered": 499999999,
        "admin": 999999999
    }
    
    if user_id > limits.get(user_type, float('inf')):
        raise ValueError(f"{user_type.capitalize()} user ID limit reached")
    
    id_counters[user_type] += 1
    return str(user_id)

def parse_sql_to_json(sql):
    pattern = r"CALL insert_user\((.*?)\);"
    match = re.search(pattern, sql)
    
    if not match:
        raise ValueError("Invalid SQL format")
    
    values = [v.strip().strip("'") if v.strip() != "NULL" else None for v in match.group(1).split(",")]
    
    if len(values) != 9:
        raise ValueError("Invalid number of parameters in SQL command")
    
    device_type, officer_id, name, password, phone, email, reg_date, birth_date, user_type = values
    user_type = user_type.replace("registerred_user", "registered").replace("unregisterred_user", "unregistered")
    
    user_id = generate_user_id(user_type)
    
    json_data = {
        "_id": user_id,
        "user_type": user_type,
        "device_type": device_type,
    }
    
    if user_type in ["registered", "admin"]:
        json_data["user_details"] = {
            "name": name,
            "email": email,
            "password": hash_password(password) if password else None,
            "telephone_number": phone,
            "register_date": datetime.datetime.now().isoformat(),  # Use ISO format for better timestamp compatibility
            "birth_date": birth_date
        }
    
    if user_type == "admin":
        json_data["admin_info"] = {"officerID": officer_id}
    
    return json.dumps(json_data, indent=2)

# Example SQL:
sql = "CALL insert_user('iOS', NULL, 'Sudarat Meesang', 'regpass123', '1123456789', 'sudarat.meesang@example.com', CAST(NOW() AS TIMESTAMP), '1996-10-30', 'registerred_user');"
print(parse_sql_to_json(sql)+',')
# Out:
# {
#   "_id": "500000001",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Sudarat Meesang",
#     "email": "sudarat.meesang@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1123456789",
#     "register_date": "2025-02-05T23:22:27.365315",
#     "birth_date": "1996-10-30"
#   }
# },

# %%
fromSQL = ["CALL insert_user('iOS', 113, 'Sittipong Wongsakul', 'password123', '1090123456', 'sittipong.wongsakul@example.com', CAST(NOW() AS TIMESTAMP), '1987-09-11', 'admin'); ",
    "CALL insert_user('Android', 114, 'Pimchanok Jirawat', 'password456', '1101234567', 'pimchanok.jirawat@example.com', CAST(NOW() AS TIMESTAMP), '1990-02-14', 'admin'); ",
    "CALL insert_user('Windows', 115, 'Chanin Sutharak', 'password789', '1112345678', 'chanin.sutharak@example.com', CAST(NOW() AS TIMESTAMP), '1992-12-22', 'admin'); ",
     
    "CALL insert_user('iOS', NULL, 'Sudarat Meesang', 'regpass123', '1123456789', 'sudarat.meesang@example.com', CAST(NOW() AS TIMESTAMP), '1996-10-30', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Sakchai Phongsak', 'regpass456', '1134567890', 'sakchai.phongsak@example.com', CAST(NOW() AS TIMESTAMP), '1994-04-17', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Thanyarat Rattanasak', 'regpass789', '1145678901', 'thanyarat.rattanasak@example.com', CAST(NOW() AS TIMESTAMP), '1995-03-03', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Apichart Tanthanuch', 'regpass123', '1156789012', 'apichart.tanthanuch@example.com', CAST(NOW() AS TIMESTAMP), '1991-07-25', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Kwanjai Chuchai', 'regpass456', '1167890123', 'kwanjai.chuchai@example.com', CAST(NOW() AS TIMESTAMP), '1993-01-19', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Nattanon Manachai', 'regpass789', '1178901234', 'nattanon.manachai@example.com', CAST(NOW() AS TIMESTAMP), '1990-11-10', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('iOS', 116, 'Thanakorn Rattanapong', 'password123', '1189012345', 'thanakorn.rattanapong@example.com', CAST(NOW() AS TIMESTAMP), '1988-01-22', 'admin'); ",
    "CALL insert_user('Android', 117, 'Wassana Pongsuk', 'password456', '1190123456', 'wassana.pongsuk@example.com', CAST(NOW() AS TIMESTAMP), '1991-04-25', 'admin'); ",
    "CALL insert_user('Windows', 118, 'Supaporn Raksri', 'password789', '1201234567', 'supaporn.raksri@example.com', CAST(NOW() AS TIMESTAMP), '1992-07-30', 'admin'); ",
     
    "CALL insert_user('iOS', NULL, 'Kittima Pongtavee', 'regpass123', '1212345678', 'kittima.pongtavee@example.com', CAST(NOW() AS TIMESTAMP), '1993-08-18', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Phakphum Chailai', 'regpass456', '1223456789', 'phakphum.chailai@example.com', CAST(NOW() AS TIMESTAMP), '1994-05-21', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Nirun Phonjan', 'regpass789', '1234567890', 'nirun.phonjan@example.com', CAST(NOW() AS TIMESTAMP), '1995-06-12', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Rapeeporn Thitiphan', 'regpass123', '1245678901', 'rapeeporn.thitiphan@example.com', CAST(NOW() AS TIMESTAMP), '1996-03-15', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Saranya Kittinan', 'regpass456', '1256789012', 'saranya.kittinan@example.com', CAST(NOW() AS TIMESTAMP), '1992-02-05', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Orawan Khemtong', 'regpass789', '1267890123', 'orawan.khemtong@example.com', CAST(NOW() AS TIMESTAMP), '1990-11-17', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    
   
    "CALL insert_user('iOS', 119, 'Jirawat Charoenwong', 'password123', '1278901234', 'jirawat.charoenwong@example.com', CAST(NOW() AS TIMESTAMP), '1985-02-15', 'admin'); ",
    "CALL insert_user('Android', 120, 'Piyarat Sittipong', 'password456', '1289012345', 'piyarat.sittipong@example.com', CAST(NOW() AS TIMESTAMP), '1998-06-10', 'admin'); ",
    "CALL insert_user('Windows', 121, 'Prapaporn Saengsawang', 'password789', '1290123456', 'prapaporn.saengsawang@example.com', CAST(NOW() AS TIMESTAMP), '2001-03-24', 'admin'); ",
     
    "CALL insert_user('iOS', NULL, 'Nattapol Phinyo', 'regpass123', '1301234567', 'nattapol.phinyo@example.com', CAST(NOW() AS TIMESTAMP), '1997-12-17', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Tassana Pongsathaporn', 'regpass456', '1312345678', 'tassana.pongsathaporn@example.com', CAST(NOW() AS TIMESTAMP), '2003-08-05', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Kritsanapong Srisai', 'regpass789', '1323456789', 'kritsanapong.srisai@example.com', CAST(NOW() AS TIMESTAMP), '1994-10-22', 'registerred_user'); ",
    
    "CALL insert_user('iOS', NULL, 'Panchalee Ruksa', 'regpass123', '1334567890', 'panchalee.ruksa@example.com', CAST(NOW() AS TIMESTAMP), '1999-07-30', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Viroj Phothong', 'regpass456', '1345678901', 'viroj.phothong@example.com', CAST(NOW() AS TIMESTAMP), '1990-11-25', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Sumalee Duangchun', 'regpass789', '1356789012', 'sumalee.duangchun@example.com', CAST(NOW() AS TIMESTAMP), '1986-04-14', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Atchara Sukhavasi', 'regpass123', '1367890123', 'atchara.sukhavasi@example.com', CAST(NOW() AS TIMESTAMP), '1992-01-18', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Pattaraporn Wiphatthanasri', 'regpass456', '1378901234', 'pattaraporn.wiphatthanasri@example.com', CAST(NOW() AS TIMESTAMP), '2000-09-09', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Ananya Roongkiat', 'regpass789', '1389012345', 'ananya.roongkiat@example.com', CAST(NOW() AS TIMESTAMP), '1993-12-13', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    
    "CALL insert_user('iOS', NULL, 'Amonrat Chaisiri', 'regpass123', '1390123456', 'amonrat.chaisiri@example.com', CAST(NOW() AS TIMESTAMP), '1995-02-19', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Prasert Bunkhot', 'regpass456', '1401234567', 'prasert.bunkhot@example.com', CAST(NOW() AS TIMESTAMP), '1998-08-02', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Rujira Phonrak', 'regpass789', '1412345678', 'rujira.phonrak@example.com', CAST(NOW() AS TIMESTAMP), '2000-01-10', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Pattaraporn Kittikulsri', 'regpass123', '1423456789', 'pattaraporn.kittikulsri@example.com', CAST(NOW() AS TIMESTAMP), '1994-06-22', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Sittichai Ratthanaporn', 'regpass456', '1434567890', 'sittichai.ratthanaporn@example.com', CAST(NOW() AS TIMESTAMP), '1993-09-30', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Sopida Lertwittayaporn', 'regpass789', '1445678901', 'sopida.lertwittayaporn@example.com', CAST(NOW() AS TIMESTAMP), '1988-11-04', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Thanya Phothong', 'regpass123', '1456789012', 'thanya.phothong@example.com', CAST(NOW() AS TIMESTAMP), '1991-03-12', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Nattakarn Phonghantakarn', 'regpass456', '1467890123', 'nattakarn.phonghantakarn@example.com', CAST(NOW() AS TIMESTAMP), '2001-07-14', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Anusorn Hiranratcha', 'regpass789', '1478901234', 'anusorn.hiranratcha@example.com', CAST(NOW() AS TIMESTAMP), '1997-10-08', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Chalida Boonsri', 'regpass123', '1489012345', 'chalida.boonsri@example.com', CAST(NOW() AS TIMESTAMP), '1990-01-21', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Soraya Chumphu', 'regpass456', '1490123456', 'soraya.chumphu@example.com', CAST(NOW() AS TIMESTAMP), '1992-04-17', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Krissanapong Phonchai', 'regpass789', '1501234567', 'krissanapong.phonchai@example.com', CAST(NOW() AS TIMESTAMP), '1995-05-28', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Chananchida Charoen', 'regpass123', '1512345678', 'chananchida.charoen@example.com', CAST(NOW() AS TIMESTAMP), '2000-02-25', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Orapin Chaisongkram', 'regpass456', '1523456789', 'orapin.chaisongkram@example.com', CAST(NOW() AS TIMESTAMP), '1999-11-13', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Nongluck Phuengkasem', 'regpass789', '1534567890', 'nongluck.phuengkasem@example.com', CAST(NOW() AS TIMESTAMP), '1994-06-03', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Varit Phaechan', 'regpass123', '1545678901', 'varit.phaechan@example.com', CAST(NOW() AS TIMESTAMP), '1996-12-05', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Chinwadee Tangpai', 'regpass456', '1556789012', 'chinwadee.tangpai@example.com', CAST(NOW() AS TIMESTAMP), '1998-03-22', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Peechaya Wongsuwan', 'regpass789', '1567890123', 'peechaya.wongsuwan@example.com', CAST(NOW() AS TIMESTAMP), '2002-01-09', 'registerred_user'); ",
     
    "CALL insert_user('iOS', NULL, 'Apirak Chokchaisiri', 'regpass123', '1578901234', 'apirak.chokchaisiri@example.com', CAST(NOW() AS TIMESTAMP), '1995-07-17', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Pornsuda Wongsuntharam', 'regpass456', '1589012345', 'pornsuda.wongsuntharam@example.com', CAST(NOW() AS TIMESTAMP), '1991-08-26', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Sivaporn Manodhin', 'regpass789', '1590123456', 'sivaporn.manodhin@example.com', CAST(NOW() AS TIMESTAMP), '1993-09-05', 'registerred_user'); ",
    
    "CALL insert_user('iOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    
    "CALL insert_user('iOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('iOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('iOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('iOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('macOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('macOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Linux', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('macOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Linux', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Linux', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('macOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Android', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('macOS', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Linux', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
    "CALL insert_user('Windows', NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'unregisterred_user'); ",
     
    "CALL insert_user('macOS', NULL, 'Kittichai Tanachot', 'regpass123', '1601234567', 'kittichai.tanachot@example.com', CAST(NOW() AS TIMESTAMP), '1992-07-05', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Phatcharaphon Srisai', 'regpass456', '1612345678', 'phatcharaphon.srisai@example.com', CAST(NOW() AS TIMESTAMP), '1994-11-16', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Nittaya Chaimongkhon', 'regpass789', '1623456789', 'nittaya.chaimongkhon@example.com', CAST(NOW() AS TIMESTAMP), '1988-03-30', 'registerred_user'); ",
     
    "CALL insert_user('macOS', NULL, 'Sasithorn Wongsakul', 'regpass123', '1634567890', 'sasithorn.wongsakul@example.com', CAST(NOW() AS TIMESTAMP), '1990-09-12', 'registerred_user'); ",
    "CALL insert_user('Linux', NULL, 'Natthakrit Wongphiphat', 'regpass456', '1645678901', 'natthakrit.wongphiphat@example.com', CAST(NOW() AS TIMESTAMP), '1993-05-22', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Pattawarin Sittisak', 'regpass789', '1656789012', 'pattawarin.sittisak@example.com', CAST(NOW() AS TIMESTAMP), '1995-02-18', 'registerred_user'); ",
     
    "CALL insert_user('Android', NULL, 'Sutthiporn Nontachai', 'regpass123', '1667890123', 'sutthiporn.nontachai@example.com', CAST(NOW() AS TIMESTAMP), '1996-08-20', 'registerred_user'); ",
    "CALL insert_user('macOS', NULL, 'Supaporn Srisupap', 'regpass456', '1678901234', 'supaporn.srisupap@example.com', CAST(NOW() AS TIMESTAMP), '1994-04-11', 'registerred_user'); ",
    "CALL insert_user('Linux', NULL, 'Sakda Chawpong', 'regpass789', '1689012345', 'sakda.chawpong@example.com', CAST(NOW() AS TIMESTAMP), '1992-06-25', 'registerred_user'); ",
     
    "CALL insert_user('Windows', NULL, 'Chitchai Tongsan', 'regpass123', '1690123456', 'chitchai.tongsan@example.com', CAST(NOW() AS TIMESTAMP), '1990-03-01', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Anchalee Phungpan', 'regpass456', '1701234567', 'anchalee.phungpan@example.com', CAST(NOW() AS TIMESTAMP), '1997-12-03', 'registerred_user'); ",
    "CALL insert_user('macOS', NULL, 'Napaporn Kittithavorn', 'regpass789', '1712345678', 'napaporn.kittithavorn@example.com', CAST(NOW() AS TIMESTAMP), '1991-01-15', 'registerred_user'); ",
     
    "CALL insert_user('Linux', NULL, 'Pongpat Suwichai', 'regpass123', '1723456789', 'pongpat.suwichai@example.com', CAST(NOW() AS TIMESTAMP), '1993-09-05', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Suchada Rattanaporn', 'regpass456', '1734567890', 'suchada.rattanaporn@example.com', CAST(NOW() AS TIMESTAMP), '1995-10-11', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Suthida Kasemsook', 'regpass789', '1745678901', 'suthida.kasemsook@example.com', CAST(NOW() AS TIMESTAMP), '1999-01-23', 'registerred_user'); ",
     
    "CALL insert_user('macOS', NULL, 'Nucharee Panyachai', 'regpass123', '1756789012', 'nucharee.panyachai@example.com', CAST(NOW() AS TIMESTAMP), '1991-12-30', 'registerred_user'); ",
    "CALL insert_user('Linux', NULL, 'Visanu Phattanaratchasong', 'regpass456', '1767890123', 'visanu.phattanaratchasong@example.com', CAST(NOW() AS TIMESTAMP), '1992-03-10', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Anchalee Tadsang', 'regpass789', '1778901234', 'anchalee.tadsang@example.com', CAST(NOW() AS TIMESTAMP), '1994-11-08', 'registerred_user'); ",
     
    "CALL insert_user('macOS', NULL, 'Taratip Jittikasem', 'regpass123', '1789012345', 'taratip.jittikasem@example.com', CAST(NOW() AS TIMESTAMP), '1996-07-24', 'registerred_user'); ",
    "CALL insert_user('Android', NULL, 'Patthara Phisitpanyarak', 'regpass456', '1790123456', 'patthara.phisitpanyarak@example.com', CAST(NOW() AS TIMESTAMP), '1998-04-18', 'registerred_user'); ",
    "CALL insert_user('Windows', NULL, 'Prinya Chansirikul', 'regpass789', '1801234567', 'prinya.chansirikul@example.com', CAST(NOW() AS TIMESTAMP), '1993-02-07', 'registerred_user'); "
]

for sqlcommand in fromSQL:
    print(parse_sql_to_json(sqlcommand)+',')
# Out:
# {
#   "_id": "900000001",
#   "user_type": "admin",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Sittipong Wongsakul",
#     "email": "sittipong.wongsakul@example.com",
#     "password": "hashed_password123",
#     "telephone_number": "1090123456",
#     "register_date": "2025-02-05T23:22:27.398475",
#     "birth_date": "1987-09-11"
#   },
#   "admin_info": {
#     "officerID": "113"
#   }
# },
# {
#   "_id": "900000002",
#   "user_type": "admin",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Pimchanok Jirawat",
#     "email": "pimchanok.jirawat@example.com",
#     "password": "hashed_password456",
#     "telephone_number": "1101234567",
#     "register_date": "2025-02-05T23:22:27.398985",
#     "birth_date": "1990-02-14"
#   },
#   "admin_info": {
#     "officerID": "114"
#   }
# },
# {
#   "_id": "900000003",
#   "user_type": "admin",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Chanin Sutharak",
#     "email": "chanin.sutharak@example.com",
#     "password": "hashed_password789",
#     "telephone_number": "1112345678",
#     "register_date": "2025-02-05T23:22:27.398985",
#     "birth_date": "1992-12-22"
#   },
#   "admin_info": {
#     "officerID": "115"
#   }
# },
# {
#   "_id": "500000002",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Sudarat Meesang",
#     "email": "sudarat.meesang@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1123456789",
#     "register_date": "2025-02-05T23:22:27.398985",
#     "birth_date": "1996-10-30"
#   }
# },
# {
#   "_id": "500000003",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Sakchai Phongsak",
#     "email": "sakchai.phongsak@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1134567890",
#     "register_date": "2025-02-05T23:22:27.398985",
#     "birth_date": "1994-04-17"
#   }
# },
# {
#   "_id": "500000004",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Thanyarat Rattanasak",
#     "email": "thanyarat.rattanasak@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1145678901",
#     "register_date": "2025-02-05T23:22:27.398985",
#     "birth_date": "1995-03-03"
#   }
# },
# {
#   "_id": "500000005",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Apichart Tanthanuch",
#     "email": "apichart.tanthanuch@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1156789012",
#     "register_date": "2025-02-05T23:22:27.399509",
#     "birth_date": "1991-07-25"
#   }
# },
# {
#   "_id": "500000006",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Kwanjai Chuchai",
#     "email": "kwanjai.chuchai@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1167890123",
#     "register_date": "2025-02-05T23:22:27.399509",
#     "birth_date": "1993-01-19"
#   }
# },
# {
#   "_id": "500000007",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Nattanon Manachai",
#     "email": "nattanon.manachai@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1178901234",
#     "register_date": "2025-02-05T23:22:27.399509",
#     "birth_date": "1990-11-10"
#   }
# },
# {
#   "_id": "100000001",
#   "user_type": "unregistered",
#   "device_type": "iOS"
# },
# {
#   "_id": "100000002",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000003",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "900000004",
#   "user_type": "admin",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Thanakorn Rattanapong",
#     "email": "thanakorn.rattanapong@example.com",
#     "password": "hashed_password123",
#     "telephone_number": "1189012345",
#     "register_date": "2025-02-05T23:22:27.399509",
#     "birth_date": "1988-01-22"
#   },
#   "admin_info": {
#     "officerID": "116"
#   }
# },
# {
#   "_id": "900000005",
#   "user_type": "admin",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Wassana Pongsuk",
#     "email": "wassana.pongsuk@example.com",
#     "password": "hashed_password456",
#     "telephone_number": "1190123456",
#     "register_date": "2025-02-05T23:22:27.399509",
#     "birth_date": "1991-04-25"
#   },
#   "admin_info": {
#     "officerID": "117"
#   }
# },
# {
#   "_id": "900000006",
#   "user_type": "admin",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Supaporn Raksri",
#     "email": "supaporn.raksri@example.com",
#     "password": "hashed_password789",
#     "telephone_number": "1201234567",
#     "register_date": "2025-02-05T23:22:27.400050",
#     "birth_date": "1992-07-30"
#   },
#   "admin_info": {
#     "officerID": "118"
#   }
# },
# {
#   "_id": "500000008",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Kittima Pongtavee",
#     "email": "kittima.pongtavee@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1212345678",
#     "register_date": "2025-02-05T23:22:27.400050",
#     "birth_date": "1993-08-18"
#   }
# },
# {
#   "_id": "500000009",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Phakphum Chailai",
#     "email": "phakphum.chailai@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1223456789",
#     "register_date": "2025-02-05T23:22:27.400050",
#     "birth_date": "1994-05-21"
#   }
# },
# {
#   "_id": "500000010",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Nirun Phonjan",
#     "email": "nirun.phonjan@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1234567890",
#     "register_date": "2025-02-05T23:22:27.400050",
#     "birth_date": "1995-06-12"
#   }
# },
# {
#   "_id": "500000011",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Rapeeporn Thitiphan",
#     "email": "rapeeporn.thitiphan@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1245678901",
#     "register_date": "2025-02-05T23:22:27.400050",
#     "birth_date": "1996-03-15"
#   }
# },
# {
#   "_id": "500000012",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Saranya Kittinan",
#     "email": "saranya.kittinan@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1256789012",
#     "register_date": "2025-02-05T23:22:27.400050",
#     "birth_date": "1992-02-05"
#   }
# },
# {
#   "_id": "500000013",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Orawan Khemtong",
#     "email": "orawan.khemtong@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1267890123",
#     "register_date": "2025-02-05T23:22:27.400050",
#     "birth_date": "1990-11-17"
#   }
# },
# {
#   "_id": "100000004",
#   "user_type": "unregistered",
#   "device_type": "iOS"
# },
# {
#   "_id": "100000005",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000006",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "900000007",
#   "user_type": "admin",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Jirawat Charoenwong",
#     "email": "jirawat.charoenwong@example.com",
#     "password": "hashed_password123",
#     "telephone_number": "1278901234",
#     "register_date": "2025-02-05T23:22:27.401061",
#     "birth_date": "1985-02-15"
#   },
#   "admin_info": {
#     "officerID": "119"
#   }
# },
# {
#   "_id": "900000008",
#   "user_type": "admin",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Piyarat Sittipong",
#     "email": "piyarat.sittipong@example.com",
#     "password": "hashed_password456",
#     "telephone_number": "1289012345",
#     "register_date": "2025-02-05T23:22:27.401061",
#     "birth_date": "1998-06-10"
#   },
#   "admin_info": {
#     "officerID": "120"
#   }
# },
# {
#   "_id": "900000009",
#   "user_type": "admin",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Prapaporn Saengsawang",
#     "email": "prapaporn.saengsawang@example.com",
#     "password": "hashed_password789",
#     "telephone_number": "1290123456",
#     "register_date": "2025-02-05T23:22:27.401061",
#     "birth_date": "2001-03-24"
#   },
#   "admin_info": {
#     "officerID": "121"
#   }
# },
# {
#   "_id": "500000014",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Nattapol Phinyo",
#     "email": "nattapol.phinyo@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1301234567",
#     "register_date": "2025-02-05T23:22:27.401061",
#     "birth_date": "1997-12-17"
#   }
# },
# {
#   "_id": "500000015",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Tassana Pongsathaporn",
#     "email": "tassana.pongsathaporn@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1312345678",
#     "register_date": "2025-02-05T23:22:27.401596",
#     "birth_date": "2003-08-05"
#   }
# },
# {
#   "_id": "500000016",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Kritsanapong Srisai",
#     "email": "kritsanapong.srisai@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1323456789",
#     "register_date": "2025-02-05T23:22:27.401596",
#     "birth_date": "1994-10-22"
#   }
# },
# {
#   "_id": "500000017",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Panchalee Ruksa",
#     "email": "panchalee.ruksa@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1334567890",
#     "register_date": "2025-02-05T23:22:27.401596",
#     "birth_date": "1999-07-30"
#   }
# },
# {
#   "_id": "500000018",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Viroj Phothong",
#     "email": "viroj.phothong@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1345678901",
#     "register_date": "2025-02-05T23:22:27.401596",
#     "birth_date": "1990-11-25"
#   }
# },
# {
#   "_id": "500000019",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Sumalee Duangchun",
#     "email": "sumalee.duangchun@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1356789012",
#     "register_date": "2025-02-05T23:22:27.401596",
#     "birth_date": "1986-04-14"
#   }
# },
# {
#   "_id": "500000020",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Atchara Sukhavasi",
#     "email": "atchara.sukhavasi@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1367890123",
#     "register_date": "2025-02-05T23:22:27.402124",
#     "birth_date": "1992-01-18"
#   }
# },
# {
#   "_id": "500000021",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Pattaraporn Wiphatthanasri",
#     "email": "pattaraporn.wiphatthanasri@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1378901234",
#     "register_date": "2025-02-05T23:22:27.402124",
#     "birth_date": "2000-09-09"
#   }
# },
# {
#   "_id": "500000022",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Ananya Roongkiat",
#     "email": "ananya.roongkiat@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1389012345",
#     "register_date": "2025-02-05T23:22:27.402124",
#     "birth_date": "1993-12-13"
#   }
# },
# {
#   "_id": "100000007",
#   "user_type": "unregistered",
#   "device_type": "iOS"
# },
# {
#   "_id": "100000008",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000009",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "500000023",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Amonrat Chaisiri",
#     "email": "amonrat.chaisiri@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1390123456",
#     "register_date": "2025-02-05T23:22:27.403144",
#     "birth_date": "1995-02-19"
#   }
# },
# {
#   "_id": "500000024",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Prasert Bunkhot",
#     "email": "prasert.bunkhot@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1401234567",
#     "register_date": "2025-02-05T23:22:27.403144",
#     "birth_date": "1998-08-02"
#   }
# },
# {
#   "_id": "500000025",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Rujira Phonrak",
#     "email": "rujira.phonrak@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1412345678",
#     "register_date": "2025-02-05T23:22:27.403144",
#     "birth_date": "2000-01-10"
#   }
# },
# {
#   "_id": "500000026",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Pattaraporn Kittikulsri",
#     "email": "pattaraporn.kittikulsri@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1423456789",
#     "register_date": "2025-02-05T23:22:27.403144",
#     "birth_date": "1994-06-22"
#   }
# },
# {
#   "_id": "500000027",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Sittichai Ratthanaporn",
#     "email": "sittichai.ratthanaporn@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1434567890",
#     "register_date": "2025-02-05T23:22:27.403144",
#     "birth_date": "1993-09-30"
#   }
# },
# {
#   "_id": "500000028",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Sopida Lertwittayaporn",
#     "email": "sopida.lertwittayaporn@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1445678901",
#     "register_date": "2025-02-05T23:22:27.403144",
#     "birth_date": "1988-11-04"
#   }
# },
# {
#   "_id": "500000029",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Thanya Phothong",
#     "email": "thanya.phothong@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1456789012",
#     "register_date": "2025-02-05T23:22:27.403144",
#     "birth_date": "1991-03-12"
#   }
# },
# {
#   "_id": "500000030",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Nattakarn Phonghantakarn",
#     "email": "nattakarn.phonghantakarn@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1467890123",
#     "register_date": "2025-02-05T23:22:27.403670",
#     "birth_date": "2001-07-14"
#   }
# },
# {
#   "_id": "500000031",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Anusorn Hiranratcha",
#     "email": "anusorn.hiranratcha@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1478901234",
#     "register_date": "2025-02-05T23:22:27.403670",
#     "birth_date": "1997-10-08"
#   }
# },
# {
#   "_id": "500000032",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Chalida Boonsri",
#     "email": "chalida.boonsri@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1489012345",
#     "register_date": "2025-02-05T23:22:27.403670",
#     "birth_date": "1990-01-21"
#   }
# },
# {
#   "_id": "500000033",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Soraya Chumphu",
#     "email": "soraya.chumphu@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1490123456",
#     "register_date": "2025-02-05T23:22:27.403670",
#     "birth_date": "1992-04-17"
#   }
# },
# {
#   "_id": "500000034",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Krissanapong Phonchai",
#     "email": "krissanapong.phonchai@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1501234567",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "1995-05-28"
#   }
# },
# {
#   "_id": "500000035",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Chananchida Charoen",
#     "email": "chananchida.charoen@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1512345678",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "2000-02-25"
#   }
# },
# {
#   "_id": "500000036",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Orapin Chaisongkram",
#     "email": "orapin.chaisongkram@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1523456789",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "1999-11-13"
#   }
# },
# {
#   "_id": "500000037",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Nongluck Phuengkasem",
#     "email": "nongluck.phuengkasem@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1534567890",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "1994-06-03"
#   }
# },
# {
#   "_id": "500000038",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Varit Phaechan",
#     "email": "varit.phaechan@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1545678901",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "1996-12-05"
#   }
# },
# {
#   "_id": "500000039",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Chinwadee Tangpai",
#     "email": "chinwadee.tangpai@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1556789012",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "1998-03-22"
#   }
# },
# {
#   "_id": "500000040",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Peechaya Wongsuwan",
#     "email": "peechaya.wongsuwan@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1567890123",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "2002-01-09"
#   }
# },
# {
#   "_id": "500000041",
#   "user_type": "registered",
#   "device_type": "iOS",
#   "user_details": {
#     "name": "Apirak Chokchaisiri",
#     "email": "apirak.chokchaisiri@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1578901234",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "1995-07-17"
#   }
# },
# {
#   "_id": "500000042",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Pornsuda Wongsuntharam",
#     "email": "pornsuda.wongsuntharam@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1589012345",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "1991-08-26"
#   }
# },
# {
#   "_id": "500000043",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Sivaporn Manodhin",
#     "email": "sivaporn.manodhin@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1590123456",
#     "register_date": "2025-02-05T23:22:27.404189",
#     "birth_date": "1993-09-05"
#   }
# },
# {
#   "_id": "100000010",
#   "user_type": "unregistered",
#   "device_type": "iOS"
# },
# {
#   "_id": "100000011",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000012",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "100000013",
#   "user_type": "unregistered",
#   "device_type": "iOS"
# },
# {
#   "_id": "100000014",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000015",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "100000016",
#   "user_type": "unregistered",
#   "device_type": "iOS"
# },
# {
#   "_id": "100000017",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000018",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "100000019",
#   "user_type": "unregistered",
#   "device_type": "iOS"
# },
# {
#   "_id": "100000020",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000021",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "100000022",
#   "user_type": "unregistered",
#   "device_type": "iOS"
# },
# {
#   "_id": "100000023",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000024",
#   "user_type": "unregistered",
#   "device_type": "macOS"
# },
# {
#   "_id": "100000025",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000026",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "100000027",
#   "user_type": "unregistered",
#   "device_type": "macOS"
# },
# {
#   "_id": "100000028",
#   "user_type": "unregistered",
#   "device_type": "Linux"
# },
# {
#   "_id": "100000029",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "100000030",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000031",
#   "user_type": "unregistered",
#   "device_type": "macOS"
# },
# {
#   "_id": "100000032",
#   "user_type": "unregistered",
#   "device_type": "Linux"
# },
# {
#   "_id": "100000033",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "100000034",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000035",
#   "user_type": "unregistered",
#   "device_type": "Linux"
# },
# {
#   "_id": "100000036",
#   "user_type": "unregistered",
#   "device_type": "macOS"
# },
# {
#   "_id": "100000037",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "100000038",
#   "user_type": "unregistered",
#   "device_type": "Android"
# },
# {
#   "_id": "100000039",
#   "user_type": "unregistered",
#   "device_type": "macOS"
# },
# {
#   "_id": "100000040",
#   "user_type": "unregistered",
#   "device_type": "Linux"
# },
# {
#   "_id": "100000041",
#   "user_type": "unregistered",
#   "device_type": "Windows"
# },
# {
#   "_id": "500000044",
#   "user_type": "registered",
#   "device_type": "macOS",
#   "user_details": {
#     "name": "Kittichai Tanachot",
#     "email": "kittichai.tanachot@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1601234567",
#     "register_date": "2025-02-05T23:22:27.406228",
#     "birth_date": "1992-07-05"
#   }
# },
# {
#   "_id": "500000045",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Phatcharaphon Srisai",
#     "email": "phatcharaphon.srisai@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1612345678",
#     "register_date": "2025-02-05T23:22:27.406228",
#     "birth_date": "1994-11-16"
#   }
# },
# {
#   "_id": "500000046",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Nittaya Chaimongkhon",
#     "email": "nittaya.chaimongkhon@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1623456789",
#     "register_date": "2025-02-05T23:22:27.406228",
#     "birth_date": "1988-03-30"
#   }
# },
# {
#   "_id": "500000047",
#   "user_type": "registered",
#   "device_type": "macOS",
#   "user_details": {
#     "name": "Sasithorn Wongsakul",
#     "email": "sasithorn.wongsakul@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1634567890",
#     "register_date": "2025-02-05T23:22:27.406228",
#     "birth_date": "1990-09-12"
#   }
# },
# {
#   "_id": "500000048",
#   "user_type": "registered",
#   "device_type": "Linux",
#   "user_details": {
#     "name": "Natthakrit Wongphiphat",
#     "email": "natthakrit.wongphiphat@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1645678901",
#     "register_date": "2025-02-05T23:22:27.406228",
#     "birth_date": "1993-05-22"
#   }
# },
# {
#   "_id": "500000049",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Pattawarin Sittisak",
#     "email": "pattawarin.sittisak@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1656789012",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1995-02-18"
#   }
# },
# {
#   "_id": "500000050",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Sutthiporn Nontachai",
#     "email": "sutthiporn.nontachai@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1667890123",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1996-08-20"
#   }
# },
# {
#   "_id": "500000051",
#   "user_type": "registered",
#   "device_type": "macOS",
#   "user_details": {
#     "name": "Supaporn Srisupap",
#     "email": "supaporn.srisupap@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1678901234",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1994-04-11"
#   }
# },
# {
#   "_id": "500000052",
#   "user_type": "registered",
#   "device_type": "Linux",
#   "user_details": {
#     "name": "Sakda Chawpong",
#     "email": "sakda.chawpong@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1689012345",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1992-06-25"
#   }
# },
# {
#   "_id": "500000053",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Chitchai Tongsan",
#     "email": "chitchai.tongsan@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1690123456",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1990-03-01"
#   }
# },
# {
#   "_id": "500000054",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Anchalee Phungpan",
#     "email": "anchalee.phungpan@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1701234567",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1997-12-03"
#   }
# },
# {
#   "_id": "500000055",
#   "user_type": "registered",
#   "device_type": "macOS",
#   "user_details": {
#     "name": "Napaporn Kittithavorn",
#     "email": "napaporn.kittithavorn@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1712345678",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1991-01-15"
#   }
# },
# {
#   "_id": "500000056",
#   "user_type": "registered",
#   "device_type": "Linux",
#   "user_details": {
#     "name": "Pongpat Suwichai",
#     "email": "pongpat.suwichai@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1723456789",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1993-09-05"
#   }
# },
# {
#   "_id": "500000057",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Suchada Rattanaporn",
#     "email": "suchada.rattanaporn@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1734567890",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1995-10-11"
#   }
# },
# {
#   "_id": "500000058",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Suthida Kasemsook",
#     "email": "suthida.kasemsook@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1745678901",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1999-01-23"
#   }
# },
# {
#   "_id": "500000059",
#   "user_type": "registered",
#   "device_type": "macOS",
#   "user_details": {
#     "name": "Nucharee Panyachai",
#     "email": "nucharee.panyachai@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1756789012",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1991-12-30"
#   }
# },
# {
#   "_id": "500000060",
#   "user_type": "registered",
#   "device_type": "Linux",
#   "user_details": {
#     "name": "Visanu Phattanaratchasong",
#     "email": "visanu.phattanaratchasong@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1767890123",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1992-03-10"
#   }
# },
# {
#   "_id": "500000061",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Anchalee Tadsang",
#     "email": "anchalee.tadsang@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1778901234",
#     "register_date": "2025-02-05T23:22:27.407243",
#     "birth_date": "1994-11-08"
#   }
# },
# {
#   "_id": "500000062",
#   "user_type": "registered",
#   "device_type": "macOS",
#   "user_details": {
#     "name": "Taratip Jittikasem",
#     "email": "taratip.jittikasem@example.com",
#     "password": "hashed_regpass123",
#     "telephone_number": "1789012345",
#     "register_date": "2025-02-05T23:22:27.408571",
#     "birth_date": "1996-07-24"
#   }
# },
# {
#   "_id": "500000063",
#   "user_type": "registered",
#   "device_type": "Android",
#   "user_details": {
#     "name": "Patthara Phisitpanyarak",
#     "email": "patthara.phisitpanyarak@example.com",
#     "password": "hashed_regpass456",
#     "telephone_number": "1790123456",
#     "register_date": "2025-02-05T23:22:27.408571",
#     "birth_date": "1998-04-18"
#   }
# },
# {
#   "_id": "500000064",
#   "user_type": "registered",
#   "device_type": "Windows",
#   "user_details": {
#     "name": "Prinya Chansirikul",
#     "email": "prinya.chansirikul@example.com",
#     "password": "hashed_regpass789",
#     "telephone_number": "1801234567",
#     "register_date": "2025-02-05T23:22:27.408571",
#     "birth_date": "1993-02-07"
#   }
# },
